# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_Han/Federal Emergencies and Disasters, 1953-Present.csv')
df.head()
# Out:
#   Declaration Number Declaration Type Declaration Date State County  \
# 0               DR-1         Disaster       05/02/1953    GA    NaN
# 1               DR-2         Disaster       05/15/1953    TX    NaN
# 2               DR-3         Disaster       05/29/1953    LA    NaN
# 3               DR-4         Disaster       06/02/1953    MI    NaN
# 4               DR-5         Disaster       06/06/1953    MT    NaN
#
#   Disaster Type              Disaster Title  Start Date    End Date  \
# 0       Tornado                     Tornado  05/02/1953  05/02/1953
# 1       Tornado  Tornado and Heavy Rainfall  05/15/1953  05/15/1953
# 2         Flood                       Flood  05/29/1953  05/29/1953
# 3       Tornado                     Tornado  06/02/1953  06/02/1953
# 4         Flood                      Floods  06/06/1953  06/06/1953
#
#    Close Date Individual Assistance Program Individuals & Households Program  \
# ...

# %%
df['County'].str.contains('King').value_counts()
# Out:
# False    45799
# True       189
# Name: County, dtype: int64

# %%
df = pd.read_csv('data_Han/KCSO_Incident_Dataset__Historic_to_2019.csv')
df.head()
# Out:
#   case_number       incident_datetime     incident_type  FCR  \
# 0   C19046940  12/09/2019 09:02:00 AM             Other  503
# 1   C19046039  12/02/2019 06:01:00 PM             Other  162
# 2   C19026684  07/14/2019 01:29:00 AM  Vehicle Recovery  311
# 3   C19043968  11/16/2019 10:07:00 PM           Traffic  404
# 4   C19042199  11/04/2019 07:18:00 AM    Property Crime  313
#
#                                  address_1     city state    zip  \
# 0                 1 Block AVE & YESLER WAY  SEATTLE    WA  98104
# 1                  19700 Block 635TH PL NE   BARING    WA  98224
# 2  1 Block PL S & DES MOINES MEMORIAL DR S   BURIEN    WA  98168
# 3             RAINIER AVE N & RENTON AVE S   SKYWAY    WA  98178
# 4  1 Block PL S & DES MOINES MEMORIAL DR S   BURIEN    WA  98168
#
#                created_at              updated_at  hour_of_day day_of_week  \
# 0  12/12/2019 06:19:00 PM  12/12/2019 08:07:00 PM            9      Monday
# ...

# %%
df = pd.read_csv('data_Han/KCSO_Offense_Reports__2020_to_Present.csv')
df.head()
# Out:
# C:\Users\yanha\AppData\Local\Temp\ipykernel_30604\186385548.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data_Han/KCSO_Offense_Reports__2020_to_Present.csv')
#   case_number       incident_datetime nibrs_code  \
# 0   C20000090  12/27/2019 06:00:00 AM        23F
# 1   C20000045  12/31/2019 09:00:00 PM        290
# 2   C20000380  01/04/2020 01:08:00 AM        35B
# 3   C20000144  01/02/2020 12:00:00 AM        23F
# 4   C20000796  01/06/2020 04:00:00 PM        23H
#
#                             nibrs_code_name                     block_address  \
# 0                  Theft From Motor Vehicle  13300 Block NEWCASTLE COMMONS DR
# 1  Destruction/Damage/Vandalism of Property             10100 Block 8TH AVE S
# 2                 Drug Equipment Violations    16500 Block INTERNATIONAL BLVD
# 3                  Theft From Motor Vehicle         11600 Block RAINIER AVE S
# ...

# %%
df = pd.read_csv('data_Han/us_disaster_declarations.csv')
df.head()
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# 2  1953-05-29T00:00:00Z         1953         Flood                     Flood
# 3  1953-06-02T00:00:00Z         1953       Tornado                   Tornado
# 4  1953-06-06T00:00:00Z         1953         Flood                    Floods
#
#    ih_program_declared  ia_program_declared  ...     incident_end_date  \
# ...

# %%
df = pd.read_csv('data_Han/us_disasters_m5.csv')
df.head()
# Out:
#    disaster_number state declaration_type      declaration_date incident_type  \
# 0             2862    TX               FM  2011-02-28T03:12:00Z          Fire
# 1             2863    TX               FM  2011-02-28T03:25:00Z          Fire
# 2             2864    TX               FM  2011-02-28T03:37:00Z          Fire
# 3             2865    TX               FM  2011-02-28T05:55:00Z          Fire
# 4             2867    TX               FM  2011-03-12T00:32:00Z          Fire
#
#                  declaration_title  ih_program_declared  ia_program_declared  \
# 0  Willow Creek South Fire Complex                    0                    0
# 1                     Matador Fire                    0                    0
# 2          Tanglewood Fire Complex                    0                    0
# 3            Mitchell Fire Complex                    0                    0
# 4                       Enmin Fire                    0                    0
#
# ...
