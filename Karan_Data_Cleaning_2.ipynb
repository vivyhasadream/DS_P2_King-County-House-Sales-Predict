# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder

# %%
main_df = pd.read_csv('data_Karan/main_df')

# %%
main_df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      6762700020  2014-10-13  7700000.0         6       8.00        12050
# 1      9808700762  2014-06-11  7060000.0         5       4.50        10040
# 2      9208900037  2014-09-19  6890000.0         6       7.75         9890
# 3      8907500070  2015-04-13  5350000.0         5       5.00         8000
# 4      1247600105  2014-10-20  5110000.0         5       5.25         8010
# ...           ...         ...        ...       ...        ...          ...
# 15757  1322049150  2015-03-05    85000.0         2       1.00          910
# 15758  1523049188  2015-04-30    84000.0         2       1.00          700
# 15759  7999600180  2014-05-29    83000.0         2       1.00          900
# 15760  1623049041  2014-05-08    82500.0         2       1.00          520
# 15761  3883800011  2014-11-05    82000.0         3       1.00          860
#
# ...

# %%
main_df['condition'].value_counts()
# Out:
# Average      10221
# Good          4137
# Very Good     1254
# Fair           131
# Poor            19
# Name: condition, dtype: int64

# %%
main_df['view'].value_counts()
# Out:
# NONE         14241
# AVERAGE        688
# GOOD           348
# FAIR           245
# EXCELLENT      240
# Name: view, dtype: int64

# %%
main_df['waterfront'].value_counts()
# Out:
# NO     15642
# YES      120
# Name: waterfront, dtype: int64

# %%
main_df['grade'].value_counts()
# Out:
# Average        6539
# Good           4438
# Better         1920
# Low Average    1482
# Very Good       832
# Excellent       290
# Low             184
# Luxury           66
# Mansion          11
# Name: grade, dtype: int64

# %% [markdown]
# ORDINAL ENCODING FOR main_df

# %%
ord_value_selector = ['condition','view','waterfront','grade']
value_subset = main_df[ord_value_selector]
value_subset
# Out:
#       condition       view waterfront        grade
# 0          Good       GOOD         NO      Mansion
# 1       Average    AVERAGE        YES    Excellent
# 2       Average  EXCELLENT         NO      Mansion
# 3       Average  EXCELLENT         NO       Luxury
# 4       Average  EXCELLENT        YES       Luxury
# ...         ...        ...        ...          ...
# 15757   Average       NONE         NO          Low
# 15758   Average       NONE         NO  Low Average
# 15759   Average       NONE         NO          Low
# 15760      Fair       NONE         NO          Low
# 15761   Average       NONE         NO  Low Average
#
# [15762 rows x 4 columns]

# %%
condition_list = ['Poor', 'Fair', 'Average', 'Good', 'Very Good'] 
view_list = ['NONE','FAIR','AVERAGE','GOOD','EXCELLENT']
waterfront_list = ['NO','YES']
grade_list = ['Low','Low Average','Average','Good','Better','Very Good','Luxury','Excellent','Mansion']

# %%
o_enc = OrdinalEncoder(categories = [condition_list,view_list,waterfront_list,grade_list])
o_enc.fit(value_subset)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Fair', 'Average', 'Good', 'Very Good'],
#                            ['NONE', 'FAIR', 'AVERAGE', 'GOOD', 'EXCELLENT'],
#                            ['NO', 'YES'],
#                            ['Low', 'Low Average', 'Average', 'Good', 'Better',
#                             'Very Good', 'Luxury', 'Excellent', 'Mansion']])

# %%
X_subset = pd.DataFrame(o_enc.transform(value_subset),
                        columns = value_subset.columns)
X_subset
# Out:
#        condition  view  waterfront  grade
# 0            3.0   3.0         0.0    8.0
# 1            2.0   2.0         1.0    7.0
# 2            2.0   4.0         0.0    8.0
# 3            2.0   4.0         0.0    6.0
# 4            2.0   4.0         1.0    6.0
# ...          ...   ...         ...    ...
# 15757        2.0   0.0         0.0    0.0
# 15758        2.0   0.0         0.0    1.0
# 15759        2.0   0.0         0.0    0.0
# 15760        1.0   0.0         0.0    0.0
# 15761        2.0   0.0         0.0    1.0
#
# [15762 rows x 4 columns]

# %%
value_subset
# Out:
#       condition       view waterfront        grade
# 0          Good       GOOD         NO      Mansion
# 1       Average    AVERAGE        YES    Excellent
# 2       Average  EXCELLENT         NO      Mansion
# 3       Average  EXCELLENT         NO       Luxury
# 4       Average  EXCELLENT        YES       Luxury
# ...         ...        ...        ...          ...
# 15757   Average       NONE         NO          Low
# 15758   Average       NONE         NO  Low Average
# 15759   Average       NONE         NO          Low
# 15760      Fair       NONE         NO          Low
# 15761   Average       NONE         NO  Low Average
#
# [15762 rows x 4 columns]

# %%
X_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15762 entries, 0 to 15761
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   condition   15762 non-null  float64
#  1   view        15762 non-null  float64
#  2   waterfront  15762 non-null  float64
#  3   grade       15762 non-null  float64
# dtypes: float64(4)
# memory usage: 492.7 KB

# %%
main_df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      6762700020  2014-10-13  7700000.0         6       8.00        12050
# 1      9808700762  2014-06-11  7060000.0         5       4.50        10040
# 2      9208900037  2014-09-19  6890000.0         6       7.75         9890
# 3      8907500070  2015-04-13  5350000.0         5       5.00         8000
# 4      1247600105  2014-10-20  5110000.0         5       5.25         8010
# ...           ...         ...        ...       ...        ...          ...
# 15757  1322049150  2015-03-05    85000.0         2       1.00          910
# 15758  1523049188  2015-04-30    84000.0         2       1.00          700
# 15759  7999600180  2014-05-29    83000.0         2       1.00          900
# 15760  1623049041  2014-05-08    82500.0         2       1.00          520
# 15761  3883800011  2014-11-05    82000.0         3       1.00          860
#
# ...

# %%
main_df['condtion'] = X_subset['condition']
main_df['view'] = X_subset['view']
main_df['waterfront'] = X_subset['waterfront']
main_df['grade'] = X_subset['grade']

# %%
main_df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      6762700020  2014-10-13  7700000.0         6       8.00        12050
# 1      9808700762  2014-06-11  7060000.0         5       4.50        10040
# 2      9208900037  2014-09-19  6890000.0         6       7.75         9890
# 3      8907500070  2015-04-13  5350000.0         5       5.00         8000
# 4      1247600105  2014-10-20  5110000.0         5       5.25         8010
# ...           ...         ...        ...       ...        ...          ...
# 15757  1322049150  2015-03-05    85000.0         2       1.00          910
# 15758  1523049188  2015-04-30    84000.0         2       1.00          700
# 15759  7999600180  2014-05-29    83000.0         2       1.00          900
# 15760  1623049041  2014-05-08    82500.0         2       1.00          520
# 15761  3883800011  2014-11-05    82000.0         3       1.00          860
#
# ...

# %%
df1 = main_df.drop(main_df.columns[[10]],axis = 1)

# %%
df1
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      6762700020  2014-10-13  7700000.0         6       8.00        12050
# 1      9808700762  2014-06-11  7060000.0         5       4.50        10040
# 2      9208900037  2014-09-19  6890000.0         6       7.75         9890
# 3      8907500070  2015-04-13  5350000.0         5       5.00         8000
# 4      1247600105  2014-10-20  5110000.0         5       5.25         8010
# ...           ...         ...        ...       ...        ...          ...
# 15757  1322049150  2015-03-05    85000.0         2       1.00          910
# 15758  1523049188  2015-04-30    84000.0         2       1.00          700
# 15759  7999600180  2014-05-29    83000.0         2       1.00          900
# 15760  1623049041  2014-05-08    82500.0         2       1.00          520
# 15761  3883800011  2014-11-05    82000.0         3       1.00          860
#
# ...
