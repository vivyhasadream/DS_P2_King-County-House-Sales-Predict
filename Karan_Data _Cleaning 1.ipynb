# %%
import pandas as pd

# %%
df = pd.read_csv('data/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
#number of unique values in all the comumns of the dataframe respectively
df.nunique()
# Out:
# id               21420
# date               372
# price             3622
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      304
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# dtype: int64

# %%
#df statistics
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %%
#df with sorted values
new_df = df.sort_values('price', ascending = False)
new_df.head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
#
#       sqft_lot  floors waterfront       view  ...         grade sqft_above  \
# 7245     27600     2.5         NO       GOOD  ...    13 Mansion       8570
# 3910     37325     2.0        YES    AVERAGE  ...  11 Excellent       7680
# 9245     31374     2.0         NO  EXCELLENT  ...    13 Mansion       8860
# 4407     35069     2.0         NO       NONE  ...    13 Mansion       6200
# 1446     23985     2.0         NO  EXCELLENT  ...     12 Luxury       6720
#
# ...

# %%
new_df.tail()
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 2139   1623049041   5/8/2014  82500.0         2       1.00          520
# 8267   3883800011  11/5/2014  82000.0         3       1.00          860
# 16184  3028200080  3/24/2015  81000.0         2       1.00          730
# 465    8658300340  5/23/2014  80000.0         1       0.75          430
# 15279    40000362   5/6/2014  78000.0         2       1.00          780
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 2139      22334     1.0         NO  NONE  ...         5 Fair        520
# 8267      10426     1.0         NO  NONE  ...  6 Low Average        860
# 16184      9975     1.0        NaN  NONE  ...         5 Fair        730
# 465        5050     1.0        NaN  NONE  ...          4 Low        430
# 15279     16344     1.0         NO  NONE  ...         5 Fair        780
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#checking for unique values in the grade column
new_df['grade'].value_counts()
# Out:
# 7 Average        8974
# 8 Good           6065
# 9 Better         2615
# 6 Low Average    2038
# 10 Very Good     1134
# 11 Excellent      399
# 5 Fair            242
# 12 Luxury          89
# 4 Low              27
# 13 Mansion         13
# 3 Poor              1
# Name: grade, dtype: int64

# %%
#checking for sum of all the null values in the columns
new_df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#viewing the columns and dropping the columns not needed
new_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
new_df.drop(['lat','long'],axis=1, inplace = True)

# %%
new_df.head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
#
#       sqft_lot  floors waterfront       view condition         grade  \
# 7245     27600     2.5         NO       GOOD      Good    13 Mansion
# 3910     37325     2.0        YES    AVERAGE   Average  11 Excellent
# 9245     31374     2.0         NO  EXCELLENT   Average    13 Mansion
# 4407     35069     2.0         NO       NONE   Average    13 Mansion
# 1446     23985     2.0         NO  EXCELLENT   Average     12 Luxury
#
#       sqft_above sqft_basement  yr_built  yr_renovated  zipcode  \
# ...

# %%
new_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %%
#dropping rows with the null values
#checking for null values
new_df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#dropping all of the null values
new_df.dropna(inplace=True)

# %%
#making sure there are no null values
new_df.isnull().sum().any()
# Out:
# False

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 7245 to 8267
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15762 non-null  int64
#  1   date           15762 non-null  object
#  2   price          15762 non-null  float64
#  3   bedrooms       15762 non-null  int64
#  4   bathrooms      15762 non-null  float64
#  5   sqft_living    15762 non-null  int64
#  6   sqft_lot       15762 non-null  int64
#  7   floors         15762 non-null  float64
#  8   waterfront     15762 non-null  object
#  9   view           15762 non-null  object
#  10  condition      15762 non-null  object
#  11  grade          15762 non-null  object
#  12  sqft_above     15762 non-null  int64
#  13  sqft_basement  15762 non-null  object
#  14  yr_built       15762 non-null  int64
#  15  yr_renovated   15762 non-null  float64
#  16  zipcode        15762 non-null  int64
# ...

# %%
new_df.head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1162  1247600105  10/20/2014  5110000.0         5       5.25         8010
#
#       sqft_lot  floors waterfront       view condition         grade  \
# 7245     27600     2.5         NO       GOOD      Good    13 Mansion
# 3910     37325     2.0        YES    AVERAGE   Average  11 Excellent
# 9245     31374     2.0         NO  EXCELLENT   Average    13 Mansion
# 1446     23985     2.0         NO  EXCELLENT   Average     12 Luxury
# 1162     45517     2.0        YES  EXCELLENT   Average     12 Luxury
#
#       sqft_above sqft_basement  yr_built  yr_renovated  zipcode  \
# ...

# %%
new_df['yr_renovated'].value_counts()[0.0]
# Out:
# 15111

# %%
new_df.shape
# Out:
# (15762, 19)

# %%
#because yr_renovated has a lot of columns with the value 0.0, i would drop the column
new_df.drop(['yr_renovated'],axis=1, inplace = True)

# %%
new_df.head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1162  1247600105  10/20/2014  5110000.0         5       5.25         8010
#
#       sqft_lot  floors waterfront       view condition         grade  \
# 7245     27600     2.5         NO       GOOD      Good    13 Mansion
# 3910     37325     2.0        YES    AVERAGE   Average  11 Excellent
# 9245     31374     2.0         NO  EXCELLENT   Average    13 Mansion
# 1446     23985     2.0         NO  EXCELLENT   Average     12 Luxury
# 1162     45517     2.0        YES  EXCELLENT   Average     12 Luxury
#
#       sqft_above sqft_basement  yr_built  zipcode  sqft_living15  sqft_lot15
# ...

# %%
new_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  1.576200e+04  1.576200e+04  15762.000000  15762.000000  15762.000000
# mean   4.593364e+09  5.413172e+05      3.378949      2.120797   2084.512372
# std    2.876078e+09  3.722258e+05      0.935301      0.766772    918.617686
# min    1.000102e+06  8.200000e+04      1.000000      0.500000    370.000000
# 25%    2.125159e+09  3.210000e+05      3.000000      1.750000   1430.000000
# 50%    3.905081e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.334501e+09  6.448750e+05      4.000000      2.500000   2550.000000
# max    9.895000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built       zipcode  \
# count  1.576200e+04  15762.000000  15762.000000  15762.000000  15762.000000
# mean   1.528082e+04      1.495147   1792.775473   1971.111217  98077.558241
# ...

# %%
new_df.shape
# Out:
# (15762, 18)

# %%
new_df['grade'].value_counts()
# Out:
# 7 Average        6539
# 8 Good           4438
# 9 Better         1920
# 6 Low Average    1482
# 10 Very Good      832
# 11 Excellent      290
# 5 Fair            167
# 12 Luxury          66
# 4 Low              16
# 13 Mansion         11
# 3 Poor              1
# Name: grade, dtype: int64

# %%
new_df['date']= pd.to_datetime(new_df['date'])

# %% [markdown]
# Renaming values inside the grade column

# %%
new_df['grade'] = new_df['grade'].replace(['3 Poor','4 Low','5 Fair'],'Low')

# %%
new_df['grade'] = new_df['grade'].replace(['6 Low Average','7 Average'],['Low Average','Average'])

# %%
new_df['grade'] = new_df['grade'].replace(['9 Better','8 Good','10 Very Good'],['Better','Good','Very Good'])

# %%
new_df['grade'] = new_df['grade'].replace(['12 Luxury','11 Excellent','13 Mansion'],['Luxury','Excellent','Mansion'])

# %%
new_df['grade'].unique()
# Out:
# array(['Mansion', 'Excellent', 'Luxury', 'Very Good', 'Good', 'Better',
#        'Average', 'Low Average', 'Low'], dtype=object)

# %% [markdown]
# Creating the low, medium and high dataframes based on the grades

# %%
low = new_df.loc[(new_df.grade == 'Low') | (new_df.grade == 'Low Average ') | (new_df.grade == 'Average')]

# %%
medium = new_df.loc[(new_df.grade == 'Good') | (new_df.grade == 'Better ') | (new_df.grade == 'Very Good')]

# %%
high = new_df.loc[(new_df.grade == 'Luxury') | (new_df.grade == 'Excellent') | (new_df.grade == 'Mansion')]

# %% [markdown]
# Analysing the data to see inconsistency

# %%
low[low.bathrooms == low.bathrooms.max()]
# Out:
#              id       date     price  bedrooms  bathrooms  sqft_living  \
# 8537  424049043 2014-08-11  450000.0         9        7.5         4050
#
#       sqft_lot  floors waterfront  view condition    grade  sqft_above  \
# 8537      6504     2.0         NO  NONE   Average  Average        4050
#
#      sqft_basement  yr_built  zipcode  sqft_living15  sqft_lot15
# 8537           0.0      1996    98144           1448        3866

# %%
low[low.bedrooms == low.bedrooms.max()]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors waterfront  view  condition    grade  sqft_above  \
# 15856      6000     1.0         NO  NONE  Very Good  Average        1040
#
#       sqft_basement  yr_built  zipcode  sqft_living15  sqft_lot15
# 15856         580.0      1947    98103           1330        4700

# %%
low['bedrooms'] = low['bedrooms'].replace([33],3)
# Out:
# <ipython-input-41-adfe3024f496>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low['bedrooms'] = low['bedrooms'].replace([33],3)

# %%
low[low.bedrooms == low.bedrooms.max()]
# Out:
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 8748  1773100755 2014-08-21  520000.0        11        3.0         3000
#
#       sqft_lot  floors waterfront  view condition    grade  sqft_above  \
# 8748      4960     2.0         NO  NONE   Average  Average        2400
#
#      sqft_basement  yr_built  zipcode  sqft_living15  sqft_lot15
# 8748         600.0      1918    98106           1420        4960

# %%
medium
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 2862   4114601570 2014-11-18  3600000.0         3       3.25         5020
# 21560  9253900271 2015-01-07  3570000.0         5       4.50         4850
# 13954  3126059023 2015-03-03  3400000.0         4       3.50         4730
# 7982   9362000040 2014-06-23  3400000.0         3       4.50         5230
# 300    3225069065 2014-06-24  3080000.0         4       5.00         4550
# ...           ...        ...        ...       ...        ...          ...
# 17003    40000471 2014-06-04   170000.0         2       1.00         1500
# 16893  3530420020 2014-07-11   162950.0         2       1.00          950
# 12332  4140900270 2015-04-27   160000.0         2       1.00         1140
# 2879   3530530110 2015-02-17   149900.0         2       1.75         1090
# 18973  7399100210 2014-11-26   140000.0         3       1.50         1200
#
#        sqft_lot  floors waterfront       view condition      grade  \
# ...

# %%
high
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020 2014-10-13  7700000.0         6       8.00        12050
# 3910   9808700762 2014-06-11  7060000.0         5       4.50        10040
# 9245   9208900037 2014-09-19  6890000.0         6       7.75         9890
# 1446   8907500070 2015-04-13  5350000.0         5       5.00         8000
# 1162   1247600105 2014-10-20  5110000.0         5       5.25         8010
# ...           ...        ...        ...       ...        ...          ...
# 6148   1321720170 2014-08-17   610000.0         3       2.50         3440
# 11147  1321700030 2014-06-24   575000.0         4       2.50         4620
# 1308   7298040310 2014-05-23   556000.0         5       2.50         3840
# 17935  1560920450 2014-09-24   550000.0         4       3.00         4180
# 19082  7298050110 2015-03-03   420000.0         4       2.50         3360
#
#        sqft_lot  floors waterfront       view condition      grade  \
# ...

# %%
low.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  6.723000e+03  6.723000e+03  6723.000000  6723.000000  6723.000000
# mean   4.541128e+09  3.977469e+05     3.229362     1.815559  1671.416778
# std    2.860426e+09  1.559260e+05     0.872428     0.620567   522.284459
# min    1.000102e+06  8.250000e+04     1.000000     0.500000   370.000000
# 25%    2.122059e+09  2.800000e+05     3.000000     1.500000  1300.000000
# 50%    3.878901e+09  3.700000e+05     3.000000     1.750000  1610.000000
# 75%    7.227800e+09  4.820000e+05     4.000000     2.250000  1979.500000
# max    9.842300e+09  2.050000e+06    11.000000     7.500000  4480.000000
#
#            sqft_lot       floors   sqft_above     yr_built       zipcode  \
# count  6.723000e+03  6723.000000  6723.000000  6723.000000   6723.000000
# mean   1.241656e+04     1.292280  1397.993753  1963.028261  98081.755615
# std    3.243607e+04     0.449332   449.484115    27.048505     54.965797
# ...

# %%
medium.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  5.270000e+03  5.270000e+03  5270.000000  5270.000000  5270.000000
# mean   4.723712e+09  6.271239e+05     3.556167     2.453416  2398.455408
# std    2.903064e+09  3.442544e+05     0.844851     0.593356   782.529511
# min    1.120007e+07  1.400000e+05     1.000000     1.000000   750.000000
# 25%    2.254501e+09  4.112500e+05     3.000000     2.250000  1840.000000
# 50%    4.050860e+09  5.500000e+05     4.000000     2.500000  2280.000000
# 75%    7.525503e+09  7.343750e+05     4.000000     2.500000  2830.000000
# max    9.839301e+09  3.600000e+06     9.000000     6.000000  6390.000000
#
#            sqft_lot       floors   sqft_above     yr_built       zipcode  \
# count  5.270000e+03  5270.000000  5270.000000  5270.000000   5270.000000
# mean   1.589236e+04     1.700190  2066.407590  1981.870968  98071.365844
# std    4.111496e+04     0.561513   736.069513    26.284703     50.412466
# ...

# %%
low
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 17753  7352200450 2015-01-15  2050000.0         4       3.25         3580
# 15401   777100005 2014-11-22  1650000.0         3       2.25         2750
# 7494   2525049133 2015-04-02  1400000.0         5       2.25         2640
# 17916  3625049079 2014-08-01  1350000.0         3       2.00         2070
# 15826  7351200050 2014-12-18  1340000.0         4       1.75         2300
# ...           ...        ...        ...       ...        ...          ...
# 17566  1423049019 2014-05-23    90000.0         2       1.00          580
# 3106   1721801591 2015-02-19    89950.0         1       1.00          570
# 16700  1322049150 2015-03-05    85000.0         2       1.00          910
# 18453  7999600180 2014-05-29    83000.0         2       1.00          900
# 2139   1623049041 2014-05-08    82500.0         2       1.00          520
#
#        sqft_lot  floors waterfront       view  condition    grade  sqft_above  \
# ...

# %%
new_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020 2014-10-13  7700000.0         6       8.00        12050
# 3910   9808700762 2014-06-11  7060000.0         5       4.50        10040
# 9245   9208900037 2014-09-19  6890000.0         6       7.75         9890
# 1446   8907500070 2015-04-13  5350000.0         5       5.00         8000
# 1162   1247600105 2014-10-20  5110000.0         5       5.25         8010
# ...           ...        ...        ...       ...        ...          ...
# 16700  1322049150 2015-03-05    85000.0         2       1.00          910
# 3763   1523049188 2015-04-30    84000.0         2       1.00          700
# 18453  7999600180 2014-05-29    83000.0         2       1.00          900
# 2139   1623049041 2014-05-08    82500.0         2       1.00          520
# 8267   3883800011 2014-11-05    82000.0         3       1.00          860
#
#        sqft_lot  floors waterfront       view condition        grade  \
# ...
